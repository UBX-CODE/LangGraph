# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline =llm.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = llm.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "**Title:** The Rise of AI in India: Opportunities, Challenges, and Future Prospects\n\n**I. Introduction**\n\n* Brief overview of the growing importance of Artificial Intelligence (AI) globally\n* Significance of AI in India's economic growth and development\n* Thesis statement: India is poised to become a major player in the AI landscape, driven by government initiatives, technological advancements, and entrepreneurial spirit.\n\n**II. Government Initiatives and Policies**\n\n* Overview of the Indian government's AI strategy and policies\n* Key initiatives:\n\t+ National AI Portal\n\t+ AI for All program\n\t+ AI for Social Good initiative\n\t+ Data Governance Framework\n* Analysis of the impact of these initiatives on the growth of AI in India\n\n**III. Technological Advancements**\n\n* Overview of the key AI technologies being developed in India:\n\t+ Machine Learning (ML)\n\t+ Natural Language Processing (NLP)\n\t+ Computer Vision\n\t+ Robotics\n* Discussion of the role of Indian startups and research institutions in driving innovation in AI\n\n**IV. AI Adoption in Key Sectors**\n\n* Overview of AI adoption in various sectors:\n\t+ Healthcare\n\t+ Finance\n\t+ Education\n\t+ Manufacturing\n\t+ Transportation\n* Case studies of successful AI implementations in these sectors\n\n**V. Challenges and Concerns**\n\n* Discussion of the challenges and concerns related to AI adoption in India:\n\t+ Data quality and availability\n\t+ Cybersecurity risks\n\t+ Job displacement\n\t+ Bias and fairness in AI decision-making\n* Analysis of the potential solutions to these challenges\n\n**VI. Future Prospects and Opportunities**\n\n* Overview of the future prospects and opportunities for AI in India:\n\t+ Growing demand for AI talent\n\t+ Increasing investment in AI startups\n\t+ Potential for AI to drive economic growth and development\n* Discussion of the potential applications of AI in emerging areas:\n\t+ Agriculture\n\t+ Energy\n\t+ Water management\n\n**VII. Conclusion**\n\n* Recap of the key points discussed in the blog\n* Final thoughts on the significance of AI in India's future growth and development\n\n**VIII. Recommendations**\n\n* Recommendations for policymakers, entrepreneurs, and individuals interested in AI:\n\t+ Encourage AI education and training programs\n\t+ Support AI research and development\n\t+ Foster a culture of innovation and experimentation\n\n**IX. References**\n\n* List of sources cited in the blog, including academic papers, news articles, and government reports.\n\n**X. Appendices**\n\n* Additional information or data that may be of interest to readers, such as:\n\t+ AI job market trends in India\n\t+ AI startup ecosystem in India\n\t+ AI policy and regulatory framework in India", 'content': '**The Rise of AI in India: Opportunities, Challenges, and Future Prospects**\n\n**I. Introduction**\n\nArtificial Intelligence (AI) has become a transformative force globally, revolutionizing industries and transforming the way we live and work. In India, AI is poised to play a significant role in the country\'s economic growth and development. The Indian government has recognized the potential of AI and has launched several initiatives to promote its adoption and development. This blog will explore the rise of AI in India, its opportunities, challenges, and future prospects.\n\nThe growing importance of AI globally is driven by its ability to automate tasks, improve efficiency, and enhance decision-making. AI has the potential to drive economic growth, create new job opportunities, and improve the quality of life for citizens. In India, AI is seen as a key driver of economic growth, with the potential to create new industries, jobs, and opportunities.\n\nThe Indian government has recognized the potential of AI and has launched several initiatives to promote its adoption and development. The government\'s AI strategy and policies aim to create a favorable ecosystem for AI inn ...

# %%
print(final_state['outline'])
# Out:
# **Title:** The Rise of AI in India: Opportunities, Challenges, and Future Prospects
#
# **I. Introduction**
#
# * Brief overview of the growing importance of Artificial Intelligence (AI) globally
# * Significance of AI in India's economic growth and development
# * Thesis statement: India is poised to become a major player in the AI landscape, driven by government initiatives, technological advancements, and entrepreneurial spirit.
#
# **II. Government Initiatives and Policies**
#
# * Overview of the Indian government's AI strategy and policies
# * Key initiatives:
# 	+ National AI Portal
# 	+ AI for All program
# 	+ AI for Social Good initiative
# 	+ Data Governance Framework
# * Analysis of the impact of these initiatives on the growth of AI in India
#
# **III. Technological Advancements**
#
# * Overview of the key AI technologies being developed in India:
# 	+ Machine Learning (ML)
# 	+ Natural Language Processing (NLP)
# 	+ Computer Vision
# 	+ Robotics
# * Discussion of the role of Indian startups and research institutions in driving innovation in AI
#
# **IV. AI Adoption in Key Sectors**
#
# * Overview of AI adoption in various sectors:
# 	+ Healthcare
# 	+ Finance
# 	+ Education
# 	+ Manufacturing
# 	+ Transportation
# * Case studies of successful AI implementations in these sectors
#
# **V. Challenges and Concerns**
#
# * Discussion of the challenges and concerns related to AI adoption in India:
# 	+ Data quality and availability
# 	+ Cybersecurity risks
# 	+ Job displacement
# 	+ Bias and fairness in AI decision-making
# * Analysis of the potential solutions to these challenges
#
# **VI. Future Prospects and Opportunities**
#
# * Overview of the future prospects and opportunities for AI in India:
# 	+ Growing demand for AI talent
# 	+ Increasing investment in AI startups
# 	+ Potential for AI to drive economic growth and development
# * Discussion of the potential applications of AI in emerging areas:
# 	+ Agriculture
# 	+ Energy
# 	+ Water management
#
# **VII. Conclusion**
#
# * Recap of the key points discussed in the blog
# * Final thoughts on the significance of AI in India's future growth and development
#
# **VIII. Recommendations**
#
# * Recommendations for policymakers, entrepreneurs, and individuals interested in AI:
# 	+ Encourage AI education and training programs
# 	+ Support AI research and development
# 	+ Foster a culture of innovation and experimentation
#
# **IX. References**
#
# * List of sources cited in the blog, including academic papers, news articles, and government reports.
#
# **X. Appendices**
#
# * Additional information or data that may be of interest to readers, such as:
# 	+ AI job market trends in India
# 	+ AI startup ecosystem in India
# 	+ AI policy and regulatory framework in India

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Opportunities, Challenges, and Future Prospects**
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has become a transformative force globally, revolutionizing industries and transforming the way we live and work. In India, AI is poised to play a significant role in the country's economic growth and development. The Indian government has recognized the potential of AI and has launched several initiatives to promote its adoption and development. This blog will explore the rise of AI in India, its opportunities, challenges, and future prospects.
#
# The growing importance of AI globally is driven by its ability to automate tasks, improve efficiency, and enhance decision-making. AI has the potential to drive economic growth, create new job opportunities, and improve the quality of life for citizens. In India, AI is seen as a key driver of economic growth, with the potential to create new industries, jobs, and opportunities.
#
# The Indian government has recognized the potential of AI and has launched several initiatives to promote its adoption and development. The government's AI strategy and policies aim to create a favorable ecosystem for AI innovation and adoption. The thesis of this blog is that India is poised to become a major player in the AI landscape, driven by government initiatives, technological advancements, and entrepreneurial spirit.
#
# **II. Government Initiatives and Policies**
#
# The Indian government has launched several initiatives to promote AI adoption and development. Some of the key initiatives include:
#
# * **National AI Portal**: The National AI Portal is a platform that provides information and resources on AI, including research papers, case studies, and training programs.
# * **AI for All program**: The AI for All program aims to promote AI adoption in various sectors, including healthcare, finance, and education.
# * **AI for Social Good initiative**: The AI for Social Good initiative aims to use AI to address social and environmental challenges, such as poverty, inequality, and climate change.
# * **Data Governance Framework**: The Data Governance Framework aims to ensure the responsible use of data in AI development and deployment.
#
# These initiatives have had a significant impact on the growth of AI in India. They have created a favorable ecosystem for AI innovation and adoption, and have helped to build a community of AI researchers, developers, and users.
#
# **III. Technological Advancements**
#
# India has made significant progress in AI research and development, with several key technologies being developed in the country. Some of the key AI technologies being developed in India include:
#
# * **Machine Learning (ML)**: ML is a type of AI that enables machines to learn from data and improve their performance over time. Indian researchers have made significant contributions to ML, including the development of new algorithms and techniques.
# * **Natural Language Processing (NLP)**: NLP is a type of AI that enables machines to understand and generate human language. Indian researchers have made significant contributions to NLP, including the development of new algorithms and techniques.
# * **Computer Vision**: Computer Vision is a type of AI that enables machines to interpret and understand visual data from images and videos. Indian researchers have made significant contributions to Computer Vision, including the development of new algorithms and techniques.
# * **Robotics**: Robotics is a type of AI that enables machines to interact with and manipulate the physical world. Indian researchers have made significant contributions to Robotics, including the development of new algorithms and techniques.
#
# Indian startups and research institutions have played a significant role in driving innovation in AI. Several Indian startups have developed AI-powered products and services, including chatbots, virtual assistants, and predictive analytics platforms. Research institutions such as the Indian Institute of Technology (IIT) and the Indian Institute of Science (IISc) have also made significant contributions to AI research and development.
#
# **IV. AI Adoption in Key Sectors**
#
# AI is being adopted in various sectors in India, including:
#
# * **Healthcare**: AI is being used in healthcare to improve patient outcomes, reduce costs, and enhance the quality of care. For example, AI-powered chatbots are being used to provide patient support and answer medical queries.
# * **Finance**: AI is being used in finance to improve risk management, enhance customer experience, and reduce costs. For example, AI-powered chatbots are being used to provide customer support and answer financial queries.
# * **Education**: AI is being used in education to improve student outcomes, enhance teacher effectiveness, and reduce costs. For example, AI-powered adaptive learning platforms are being used to provide personalized learning experiences for students.
# * **Manufacturing**: AI is being used in manufacturing to improve productivity, reduce costs, and enhance quality. For example, AI-powered predictive maintenance platforms are being used to predict equipment failures and reduce downtime.
# * **Transportation**: AI is being used in transportation to improve safety, reduce costs, and enhance customer experience. For example, AI-powered autonomous vehicles are being developed to improve road safety and reduce traffic congestion.
#
# Case studies of successful AI implementations in these sectors include:
#
# * **AI-powered chatbots in healthcare**: AI-powered chatbots are being used in healthcare to provide patient support and answer medical queries. For example, the AI-powered chatbot "Mfine" is being used to provide patient support and answer medical queries in several hospitals in India.
# * **AI-powered predictive maintenance in manufacturing**: AI-powered predictive maintenance platforms are being used in manufacturing to predict equipment failures and reduce downtime. For example, the AI-powered predictive maintenance platform "Predii" is being used to predict equipment failures and reduce downtime in several manufacturing plants in India.
#
# **V. Challenges and Concerns**
#
# Despite the significant progress made in AI research and development, there are several challenges and concerns related to AI adoption in India. Some of the key challenges and concerns include:
#
# * **Data quality and availability**: AI requires high-quality and large amounts of data to learn and improve. However, data quality and availability are significant challenges in India, particularly in sectors such as healthcare and finance.
# * **Cybersecurity risks**: AI systems are vulnerable to cybersecurity risks, particularly in sectors such as finance and healthcare. For example, AI-powered chatbots can be hacked to steal sensitive information or disrupt critical systems.
# * **Job displacement**: AI has the potential to displace jobs, particularly in sectors such as manufacturing and transportation. For example, AI-powered autonomous vehicles can displace human drivers.
# * **Bias and fairness in AI decision-making**: AI systems can perpetuate bias and unfairness in decision-making, particularly in sectors such as finance and healthcare. For example, AI-powered credit scoring systems can perpetuate bias and unfairness in lending decisions.
#
# Potential solutions to these challenges include:
#
# * **Data governance frameworks**: Data governance frameworks can help ensure the responsible use of data in AI development and deployment.
# * **Cybersecurity measures**: Cybersecurity measures such as encryption, firewalls, and intrusion detection systems can help protect AI systems from cybersecurity risks.
# * **Upskilling and reskilling**: Upskilling and reskilling programs can help workers develop the skills they need to work with AI systems.
# * **Bias and fairness detection tools**: Bias and fairness detection tools can help detect and mitigate bias and unfairness in AI decision-making.
#
# **VI. Future Prospects and Opportunities**
#
# The future prospects and opportunities for AI in India are significant. Some of the key opportunities include:
#
# * **Growing demand for AI talent**: The demand for AI talent is growing rapidly in India, particularly in sectors such as finance and healthcare.
# * **Increasing investment in AI startups**: Investment in AI startups is increasing rapidly in India, particularly in sectors such as healthcare and finance.
# * **Potential for AI to drive economic growth and development**: AI has the potential to drive economic growth and development in India, particularly in sectors such as manufacturing and transportation.
#
# Emerging areas where AI can have a significant impact include:
#
# * **Agriculture**: AI can help improve crop yields, reduce costs, and enhance the quality of agricultural products.
# * **Energy**: AI can help improve energy efficiency, reduce costs, and enhance the quality of energy services.
# * **Water management**: AI can help improve water management, reduce costs, and enhance the quality of water services.
#
# **VII. Conclusion**
#
# In conclusion, the rise of AI in India is a significant development that has the potential to drive economic growth and development. The Indian government's initiatives and policies have created a favorable ecosystem for AI innovation and adoption, and several Indian startups and research institutions have made significant contributions to AI research and development. However, there are several challenges and concerns related to AI adoption in India, including data quality and availability, cybersecurity risks, job displacement, and bias and fairness in AI decision-making. Potential solutions to these challenges include data governance frameworks, cybersecurity measures, upskilling and reskilling programs, and bias and fairness detection tools.
#
# **VIII. Recommendations**
#
# Based on the analysis and discussion in this blog, the following recommendations are made:
#
# * **Encourage AI education and training programs**: Encourage AI education and training programs to develop the skills and talent needed to work with AI systems.
# * **Support AI research and development**: Support AI research and development to drive innovation and adoption in various sectors.
# * **Foster a culture of innovation and experimentation**: Foster a culture of innovation and experimentation to encourage the development of new AI-powered products and services.
#
# **IX. References**
#
# This blog has cited several sources, including academic papers, news articles, and government reports. Some of the key sources include:
#
# * **National AI Portal**: National AI Portal. (2022). AI Strategy and Policies.
# * **AI for All program**: AI for All program. (2022). AI for All program: A Framework for AI Adoption in India.
# * **AI for Social Good initiative**: AI for Social Good initiative. (2022). AI for Social Good: A Framework for AI Adoption in India.
# * **Data Governance Framework**: Data Governance Framework. (2022). Data Governance Framework: A Framework for Responsible Data Use in AI Development and Deployment.
#
# **X. Appendices**
#
# This blog includes several appendices, including:
#
# * **AI job market trends in India**: AI job market trends in India, including the demand for AI talent and the growth of AI-related job postings.
# * **

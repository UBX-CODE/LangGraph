# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.',
#  'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-12fc-6e51-8002-f89b7d6747e1'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-02T08:27:31.376494+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0e07-6c91-8001-8341b86d7472'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.', 'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-12fc-6e51-8002-f89b7d6747e1'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-02T08:27:31.376494+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0e07-6c91-8001-8341b86d7472'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0e07-6c91-8001-8341b86d7472'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-02T08:27:30.856667+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0850-6ee5-8000-5fb64e102910'}}, tasks=(PregelTask(id='261a99c2-9b0c-3102-1b3d-5dbaeb4b708f', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke "Why did the pizza go to the doctor? Because it was feeling a little crusty" is a play on words. It uses a pun to create humor.\n\nIn this joke, "crusty" has a double meaning. A pizza crust is the outer layer of a pizza, which is typically made of bread or dough. However, "crusty" can also mean irritable or having a rough temperament, similar to how someone might feel when they\'re not feeling well.\n\nThe joke relies on this wordplay to create a pun, which is a form of wordplay that exploits multiple meanings of a word or phrase. The punchline "feeling a little crusty" is a clever connection between the pizza\'s physical crust and the idea of feeling unwell, making it a clever and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0850-6ee5-8000-5fb64e102910'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-02T08:27:30.257482+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0844-64d9-bfff-dcda272e034a'}}, tasks=(PregelTask(id='c9152bf3-6b68-48c4-e157-72bb332c49cc', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to the doctor? \n\nBecause it was feeling a little crusty.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c0-0844-64d9-bfff-dcda272e034a'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-02T08:27:30.252309+00:00', parent_config=None, tasks=(PregelTask(id='030fda38-395f-8e6b-6e52-e21490986b1d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."',
#  'explanation': 'The joke relies on a play on words. The phrase "feeling a little twisted" has a double meaning here. \n\nIn one sense, "twisted" can refer to a mental state of being emotionally disturbed or having psychological issues, which is why someone might go to therapy. This is the context in which the phrase is typically used.\n\nHowever, in the context of the joke, "twisted" also refers to the physical state of spaghetti, which is a type of pasta that is long and curved, often twisted into various shapes. This is a clever pun, as the wordplay connects the idea of the spaghetti\'s physical appearance to its emotional state, creating a humorous connection between the two.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."', 'explanation': 'The joke relies on a play on words. The phrase "feeling a little twisted" has a double meaning here. \n\nIn one sense, "twisted" can refer to a mental state of being emotionally disturbed or having psychological issues, which is why someone might go to therapy. This is the context in which the phrase is typically used.\n\nHowever, in the context of the joke, "twisted" also refers to the physical state of spaghetti, which is a type of pasta that is long and curved, often twisted into various shapes. This is a clever pun, as the wordplay connects the idea of the spaghetti\'s physical appearance to its emotional state, creating a humorous connection between the two.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-10ab-65c4-8002-7346bdf67d48'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-02T08:31:05.881747+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-0918-6128-8001-4dc2e76c569d'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."', 'explanation': 'The joke relies on a play on words. The phrase "feeling a little twisted" has a double meaning here. \n\nIn one sense, "twisted" can refer to a mental state of being emotionally disturbed or having psychological issues, which is why someone might go to therapy. This is the context in which the phrase is typically used.\n\nHowever, in the context of the joke, "twisted" also refers to the physical state of spaghetti, which is a type of pasta that is long and curved, often twisted into various shapes. This is a clever pun, as the wordplay connects the idea of the spaghetti\'s physical appearance to its emotional state, creating a humorous connection between the two.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-10ab-65c4-8002-7346bdf67d48'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-02T08:31:05.881747+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-0918-6128-8001-4dc2e76c569d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-0918-6128-8001-4dc2e76c569d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-02T08:31:05.086418+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-00f1-6114-8000-16f4ea2243df'}}, tasks=(PregelTask(id='0c7bea46-8585-8079-2554-4e73c201262b', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke relies on a play on words. The phrase "feeling a little twisted" has a double meaning here. \n\nIn one sense, "twisted" can refer to a mental state of being emotionally disturbed or having psychological issues, which is why someone might go to therapy. This is the context in which the phrase is typically used.\n\nHowever, in the context of the joke, "twisted" also refers to the physical state of spaghetti, which is a type of pasta that is long and curved, often twisted into various shapes. This is a clever pun, as the wordplay connects the idea of the spaghetti\'s physical appearance to its emotional state, creating a humorous connection between the two.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-00f1-6114-8000-16f4ea2243df'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-02T08:31:04.232578+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-00ed-6006-bfff-d00b20fba62a'}}, tasks=(PregelTask(id='70c7833a-5489-15bf-b1c3-6c0e4ca7336c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the spaghetti go to therapy? \n\nBecause it was feeling a little "twisted."'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f18e4c8-00ed-6006-bfff-d00b20fba62a'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-02T08:31:04.230912+00:00', parent_config=None, tasks=(PregelTask(id='2f500181-acf3-991f-7c39-80b752b8dc45', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())]
